# %%
import pandas as pd
import numpy as np
headers=["class","cap-shape","cap-surface","cap-color","bruises","odor","gill-attachment","gill-spacing","gill-size","gill-color","stalk-shape","stalk-root","stalk-surface-above-ring","stalk-surface-below-ring","stalk-color-above-ring","stalk-color-below-ring","veil-type","veil-color","ring-number","ring-type","spore-print-color","population","habitat"]
dataset_link='http://iali.in/datasets/mushrooms.csv'
dataset=pd.read_csv(dataset_link)
dataset.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
dataset.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
dataset.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
obj_dataset=dataset.select_dtypes(include=['object']).copy()
obj_dataset.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
dataset=dataset.dropna(axis=0)
dataset.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
obj_dataset["class"].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
obj_dataset = obj_dataset.fillna({"class": "e"})

# %%
obj_dataset["cap-shape"].value_counts()
# Out:
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64

# %%
obj_dataset = obj_dataset.fillna({"cap-shape": "x"})

# %%
obj_dataset["cap-surface"].value_counts()
# Out:
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64

# %%
obj_dataset = obj_dataset.fillna({"cap-surface": "y"})

# %%
obj_dataset["cap-color"].value_counts()
# Out:
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: cap-color, dtype: int64

# %%
obj_dataset = obj_dataset.fillna({"cap-color": "n"})

# %%
obj_dataset["habitat"].value_counts()
# Out:
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: habitat, dtype: int64

# %%
obj_dataset = obj_dataset.fillna({"habitat": "d"})

# %%
obj_dataset["population"].value_counts()
# Out:
# v    4040
# y    1712
# s    1248
# n     400
# a     384
# c     340
# Name: population, dtype: int64

# %%
obj_dataset = obj_dataset.fillna({"population": "v"})

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
obj_dataset["class_"] = lb_make.fit_transform(obj_dataset["class"])

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
obj_dataset["population_"] = lb_make.fit_transform(obj_dataset["population"])

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
obj_dataset["cap-shape_"] = lb_make.fit_transform(obj_dataset["cap-shape"])

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
obj_dataset["cap-surface_"] = lb_make.fit_transform(obj_dataset["cap-surface"])

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
obj_dataset["cap-color_"] = lb_make.fit_transform(obj_dataset["cap-color"])

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
obj_dataset["habitat_"] = lb_make.fit_transform(obj_dataset["habitat"])

# %%
use=obj_dataset[["population_","cap-shape_","cap-surface_","cap-color_","habitat_", "class_"]]
use.head()
# Out:
#    population_  cap-shape_  cap-surface_  cap-color_  habitat_  class_
# 0            3           5             2           4         5       1
# 1            2           5             2           9         1       0
# 2            2           0             2           8         3       0
# 3            3           5             3           8         5       1
# 4            0           5             2           3         1       0

# %%
X = use.iloc[:, [0,1,2,3,4]].values
y = use.iloc[:, 5].values

# %%
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()

clf = clf.fit(x_train, y_train)

# %%
y_prediction = clf.predict(x_test)
y_prediction
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_prediction,y_test)
# Out:
# 0.9132307692307692
